# %%
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Input Box

# %%
a = input("Enter your name:")

# %%
a
# Out:
# 'rahul'

# %%
b=2
c=int(input("Enter a number: "))
sum = b + c
print(sum)
# Out:
# 7

# %%
#create function

# %%
def prod(a):
    b = int(input("Enter a value:"))
    c=5
    p=a*b*c
    return(p)

# %%
prod(6)
# Out:
# 210

# %%
prod(7)
# Out:
# 280

# %% [markdown]
# List

# %%
list = [2,4,8,10]

# %%
list
# Out:
# [2, 4, 8, 10]

# %% [markdown]
# Dictionary

# %%
age = {"Henry":30, "Carla":19, "Benedict":24, "Dominic":15}

# %%
age
# Out:
# {'Henry': 30, 'Carla': 19, 'Benedict': 24, 'Dominic': 15}

# %% [markdown]
# WHILE Loop

# %%
count = 0
while count<=5:
    count+=1
    print("Love your country")
# Out:
# Love your country
# Love your country
# Love your country
# Love your country
# Love your country
# Love your country

# %% [markdown]
# FOR Loop

# %%
string=("Rejoice")
for i in string:
    print(i)
# Out:
# R
# e
# j
# o
# i
# c
# e

# %% [markdown]
# IF Statement

# %%
x=3*2
if x%2 == 0:
    print("It is even")
# Out:
# It is even

# %% [markdown]
# IF ELSE Statement

# %%
x=3**3
if x%2 ==0:
    print("It is even")
else:
    print("It is odd")
# Out:
# It is odd

# %% [markdown]
# Elif Statement

# %%
x=7
if x%2==0:
    print("It is divisible by 2")
elif x%3==0:
    print("It is divisible by 3")
else:
    print("It is neither divisible by 2 or 3")
# Out:
# It is neither divisible by 2 or 3
